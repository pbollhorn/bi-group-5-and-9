# %% [markdown]
# ## Lead actor/actress age at release

# %% [markdown]
# We will loook this see if there is any correlation between the lead actor/actress age at the release of the movie and the budget of that movie.

# %%
import sys
sys.path.append("..")
import ast
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from reader import generic_reader

# %% [markdown]
# First we'll make a combined dataframe of movies and persons.

# %%
df_movies = pd.read_csv("movie_data/df_movies_clean.csv")
df_persons = pd.read_csv("movie_data/df_persons_clean.csv")

## ---------Remove when combining with the clean data part -----------
# Convert stringified lists back into actual lists 
df_movies['cast_person_ids'] = df_movies['cast_person_ids'].apply(ast.literal_eval)
df_movies['director_person_ids'] = df_movies['director_person_ids'].apply(ast.literal_eval)

# Now take the first element as int
df_movies['cast_person_id'] = df_movies['cast_person_ids'].str[0].astype('Int64')
df_movies['director_person_id'] = df_movies['director_person_ids'].str[0].astype('Int64')

# %% [markdown]
# We'll look at the lead actor/actress and lead director. Our dataset have the lead director and actor/atress as the first index. We'll now take the first index of the cast_person_ids and director_person_ids aswell as change the name of the column to cast_person_id and director_person__id.

# %%
import ast
import pandas as pd

# Load cleaned data
df_movies = pd.read_csv("movie_data/df_movies_clean.csv")
df_persons = pd.read_csv("movie_data/df_persons_clean.csv")

# Convert stringified lists back to Python lists
df_movies['cast_person_ids'] = df_movies['cast_person_ids'].apply(ast.literal_eval)
df_movies['director_person_ids'] = df_movies['director_person_ids'].apply(ast.literal_eval)

# Make a copy
df_movies_first = df_movies.copy()

# Replace list columns with just the first element and rename
df_movies_first['cast_person_id'] = df_movies_first['cast_person_ids'].str[0].astype('Int64')
df_movies_first['director_person_id'] = df_movies_first['director_person_ids'].str[0].astype('Int64')

# Drop the old list columns if you don’t need them anymore
df_movies_first = df_movies_first.drop(columns=['cast_person_ids', 'director_person_ids'])

# Show the first few rows
print(df_movies_first[['cast_person_id', 'director_person_id']].head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2406 entries, 0 to 2405
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   budget               2406 non-null   int64
#  1   movie_id             2406 non-null   int64
#  2   original_title       2406 non-null   object
#  3   overview             2406 non-null   object
#  4   release_date         2406 non-null   object
#  5   revenue              2406 non-null   int64
#  6   runtime              2406 non-null   int64
#  7   vote_average         2406 non-null   float64
#  8   vote_count           2406 non-null   int64
#  9   director_person_ids  2406 non-null   Int64
#  10  genre_ids            2406 non-null   object
#  11  collection_id        786 non-null    float64
#  12  cast_person_ids      2406 non-null   Int64
#  13  cast_credit_ids      2406 non-null   object
#  14  crew_person_ids      2406 non-null   object
# ...

# %%
df_movies_first.head()
# Out:
#      budget  movie_id        original_title  \
# 0  80000000     49948         Fantasia 2000
# 1  40000000      4234              Scream 3
# 2  23000000      2787           Pitch Black
# 3  41300000      2069  The Whole Nine Yards
# 4  90000000      2067       Mission to Mars
#
#                                             overview release_date    revenue  \
# 0  Blending lively music and brilliant animation,...   2000-01-01   60655420
# 1  While Sidney Prescott and her friends visit th...   2000-02-04  161834276
# 2  When their ship crash-lands on a remote planet...   2000-02-18   53187659
# 3  After a mobster agrees to cooperate with an FB...   2000-02-18  106371651
# 4  When the first manned mission to Mars meets wi...   2000-03-10  110983407
#
#    runtime  vote_average  vote_count  director_person_ids           genre_ids  \
# 0       74         7.000        1324                 5690  [16, 10751, 10402]
# ...
