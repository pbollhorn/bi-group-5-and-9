# %%
import sys
sys.path.append("..")

import pandas as pd
import ast  # Abstract Syntax Trees - safely parse string list to Python list
import seaborn as sns
import matplotlib.pyplot as plt
from reader import generic_reader

# %% [markdown]
# ## Data wrangling

# %% [markdown]
# Our dataset of movies are movies from the USA, from the periode 1/1/2000 to 31/12/2023 and with a vote count of atleast 1000

# %%
movies = generic_reader.read_csv_file_to_data_frame("movie_data/movies.csv")
print(movies.info())
movies
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2801 entries, 0 to 2800
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   adult                   2801 non-null   bool
#  1   backdrop_path           2800 non-null   object
#  2   budget                  2801 non-null   int64
#  3   homepage                1902 non-null   object
#  4   movie_id                2801 non-null   int64
#  5   imdb_id                 2800 non-null   object
#  6   origin_country          2801 non-null   object
#  7   original_language       2801 non-null   object
#  8   original_title          2801 non-null   object
#  9   overview                2801 non-null   object
#  10  popularity              2801 non-null   float64
#  11  poster_path             2800 non-null   object
#  12  production_countries    2801 non-null   object
#  13  release_date            2801 non-null   object
#  14  revenue                 2801 non-null   int64
#  15  runtime                 2801 non-null   int64
#  16  spoken_languages        2801 non-null   object
#  17  status                  2801 non-null   object
#  18  tagline                 2684 non-null   object
#  19  title                   2801 non-null   object
#  20  video                   2801 non-null   bool
#  21  vote_average            2801 non-null   float64
#  22  vote_count              2801 non-null   int64
#  23  director_person_ids     2801 non-null   object
#  24  genre_ids               2801 non-null   object
#  25  production_company_ids  2801 non-null   object
#  26  collection_id           894 non-null    float64
#  27  cast_person_ids         2801 non-null   object
#  28  cast_credit_ids         2801 non-null   object
#  29  crew_person_ids         2801 non-null   object
#  30  crew_credit_ids         2801 non-null   object
# dtypes: bool(2), float64(3), int64(5), object(21)
# memory usage: 640.2+ KB
# None
#       adult                     backdrop_path     budget  \
# 0     False  /n92EzFFg2cMkJiEhnMfD5sKHSH3.jpg   80000000
# 1     False  /rNOeiC5uruGnr5n7YW8hvnrbX9q.jpg          0
# 2     False  /AbFWty0o5nKGo4iLJaGRgqFtC8W.jpg   40000000
# 3     False  /mZGwhwIwYuF0G9XLS8j23dhNfUC.jpg   23000000
# 4     False  /dA8CmAfzxVwNTcrUWTkunh7ZPqk.jpg   41300000
# ...     ...                               ...        ...
# 2796  False  /sRLC052ieEzkQs9dEtPMfFxYkej.jpg   83000000
# 2797  False  /bq9FpkTw9I3s1cSRuZxQibM2xOx.jpg   15000000
# 2798  False  /bckxSN9ueOgm0gJpVJmPQrecWul.jpg  205000000
# 2799  False  /j9eOeLlTGoHoM8BNUJVNyWmIvCi.jpg   25000000
# 2800  False  /4l65BWqJBl7hBwdIwp2nQdwsOuw.jpg   15900000
#
#                                              homepage  movie_id     imdb_id  \
# 0              http://movies.disney.com/fantasia-2000     49948   tt0120910
# 1                                                 NaN     10898   tt0240684
# 2                                                 NaN      4234   tt0134084
# 3             https://www.uphe.com/movies/pitch-black      2787   tt0134847
# 4                                                 NaN      2069   tt0190138
# ...                                               ...       ...         ...
# 2796           https://www.netflix.com/title/81464239    848326  tt14998742
# 2797  https://a24films.com/films/the-zone-of-interest    467244   tt7160372
# 2798                     https://www.aquamanmovie.com    572802   tt9663764
# 2799                   https://www.anyonebutyou.movie   1072790  tt26047818
# 2800                       https://ironclawmovie.com/    850165  tt21064584
#
#      origin_country original_language  \
# 0            ['US']                en
# 1            ['US']                en
# 2            ['US']                en
# 3            ['US']                en
# 4            ['US']                en
# ...             ...               ...
# 2796         ['US']                en
# 2797         ['US']                en
# 2798         ['US']                en
# 2799         ['US']                en
# 2800         ['US']                en
#
#                                 original_title  \
# 0                                Fantasia 2000
# 1     The Little Mermaid II: Return to the Sea
# 2                                     Scream 3
# 3                                  Pitch Black
# 4                         The Whole Nine Yards
# ...                                        ...
# 2796    Rebel Moon - Part One: A Child of Fire
# 2797                      The Zone of Interest
# 2798              Aquaman and the Lost Kingdom
# 2799                            Anyone But You
# 2800                             The Iron Claw
#
#                                                overview  ...  vote_average  \
# 0     Blending lively music and brilliant animation,...  ...         7.000
# 1     Set several years after the first film, Ariel ...  ...         6.397
# 2     While Sidney Prescott and her friends visit th...  ...         5.995
# 3     When their ship crash-lands on a remote planet...  ...         6.851
# 4     After a mobster agrees to cooperate with an FB...  ...         6.465
# ...                                                 ...  ...           ...
# 2796  When the ruthless forces of the Motherworld th...  ...         6.242
# 2797  The commandant of Auschwitz, Rudolf Höss, and ...  ...         7.005
# 2798  Black Manta seeks revenge on Aquaman for his f...  ...         6.600
# 2799  After an amazing first date, Bea and Ben’s fie...  ...         6.837
# 2800  The true story of the inseparable Von Erich br...  ...         7.543
#
#      vote_count                                director_person_ids  \
# 0          1324  [5690, 56146, 74299, 65531, 74297, 12824, 5614...
# 1          1747                                            [60725]
# 2          3807                                             [5140]
# 3          4599                                            [28239]
# 4          1970                                            [21217]
# ...         ...                                                ...
# 2796       2385                                            [15217]
# 2797       2304                                            [66728]
# 2798       3223                                             [2127]
# 2799       2735                                            [82511]
# 2800       1084                                           [527607]
#
#                 genre_ids                production_company_ids  \
# 0      [16, 10751, 10402]                                   [2]
# 1     [16, 12, 10751, 35]                          [3475, 5391]
# 2              [27, 9648]                      [7405, 85, 1600]
# 3           [53, 878, 28]                               [10201]
# 4                [35, 80]                        [53013, 53014]
# ...                   ...                                   ...
# 2796        [878, 28, 12]                      [114152, 156880]
# 2797      [18, 36, 10752]  [41077, 6705, 103376, 27543, 113962]
# 2798         [28, 12, 14]   [174, 11565, 76907, 128064, 216687]
# 2799          [10749, 35]             [7291, 105052, 124283, 5]
# 2800             [36, 18]          [41077, 288, 103376, 112783]
#
#       collection_id                                    cast_person_ids  \
# 0           55427.0  [67773, 166002, 13301, 73931, 15152, 37221, 74...
# 1           33085.0  [63978, 67392, 15762, 35232, 67393, 9601, 7133...
# 2            2602.0  [15234, 9206, 14405, 18352, 35595, 2714, 35598...
# 3            2794.0  [12835, 8329, 6614, 28099, 26054, 65827, 28098...
# 4          103577.0  [14408, 62, 57395, 2956, 61981, 2165, 7166, 16...
# ...             ...                                                ...
# 2796       934765.0  [568657, 91520, 1047649, 938, 21688, 1564557, ...
# 2797            NaN  [71374, 7152, 4072267, 4452138, 4072269, 40722...
# 2798       573693.0  [117642, 17178, 1639847, 79082, 55085, 2227, 1...
# 2799            NaN  [115440, 83271, 3085680, 2728596, 2495673, 125...
# 2800            NaN  [29222, 206905, 1716493, 2394927, 7497, 16307,...
#
#                                         cast_credit_ids  \
# 0     ['52fe47b1c3a36847f814324f', '547f694292514123...
# 1     ['52fe43cc9251416c7501e85d', '52fe43cc9251416c...
# 2     ['52fe43b4c3a36847f806911d', '52fe43b4c3a36847...
# 3     ['52fe436dc3a36847f80535fd', '52fe436dc3a36847...
# 4     ['52fe4331c3a36847f80418c5', '52fe4331c3a36847...
# ...                                                 ...
# 2796  ['61818dfd11386c002a9b6ed9', '6250b2765a07f500...
# 2797  ['635c3ad9f28838007b15e2fe', '635c3acb88c65900...
# 2798  ['65b4239557530e0147d981bc', '5f41dea381a7fc00...
# 2799  ['63bf14f4df857c0089269b1a', '63bf1503df857c00...
# 2800  ['6326e64edcb6a3007dd98484', '6326e637dcb6a300...
#
#                                         crew_person_ids  \
# 0     [2066428, 5690, 56146, 74299, 65531, 74297, 12...
# 1     [60725, 67394, 67395, 67396, 61386, 67397, 607...
# 2     [5140, 26458, 15244, 409, 35581, 26458, 7229, ...
# 3     [28239, 13673, 28240, 9185, 63920, 63921, 1412...
# 4     [21219, 21222, 14712, 21218, 21221, 21220, 212...
# ...                                                 ...
# 2796  [3486271, 15217, 17285, 1005508, 2104243, 1830...
# 2797  [1341727, 4222, 70604, 1623709, 1389542, 41551...
# 2798  [52600, 2127, 36, 1354914, 1545447, 62813, 212...
# 2799  [1963222, 1325188, 2761446, 4321486, 4321489, ...
# 2800  [527607, 465, 2211578, 1336431, 3987582, 32604...
#
#                                         crew_credit_ids
# 0     ['624f173b24f2ce009ddf2543', '52fe47b1c3a36847...
# 1     ['52fe43cc9251416c7501e873', '52fe43cc9251416c...
# 2     ['52fe43b4c3a36847f80690cb', '52fe43b4c3a36847...
# 3     ['52fe436dc3a36847f805361f', '52fe436dc3a36847...
# 4     ['52fe4331c3a36847f8041899', '52fe4331c3a36847...
# ...                                                 ...
# 2796  ['624462cdc50ad20047008aad', '626038010792e115...
# 2797  ['620956a6fab3fa0132ea9f79', '6078629118864b00...
# 2798  ['60774e1d19ab59004062d106', '6078ca802faf4d00...
# 2799  ['652be8e4f2883802a25e99af', '652be8fa358da700...
# 2800  ['60ed282a140bad002f076acc', '60ed284651a64e00...
#
# [2801 rows x 31 columns]

# %% [markdown]
# We make a new dataframe keeping only the columns we want to use.
# While making the dataframe we also change the genre_ids, cast_person_ids and crew_person_id from a string to Python lists and the release_date into a proper datetime format.

# %%
columns_to_keep = ['budget', 'movie_id', 'original_title', 'overview', 'release_date', 'revenue', 'runtime', 'vote_average', 'vote_count', 'director_person_ids', 'genre_ids', 'collection_id', 'cast_person_ids', 'cast_credit_ids', 'crew_person_ids', 'crew_credit_ids']
df_movies = movies[columns_to_keep].copy()

df_movies['genre_ids'] = movies['genre_ids'].apply(ast.literal_eval)
df_movies['cast_person_ids'] = movies['cast_person_ids'].apply(ast.literal_eval)
df_movies['crew_person_ids'] = movies['crew_person_ids'].apply(ast.literal_eval)
df_movies['director_person_ids'] = movies['director_person_ids'].apply(ast.literal_eval)
df_movies['release_date'] = pd.to_datetime(movies['release_date'])
df_movies
# Out:
#          budget  movie_id                            original_title  \
# 0      80000000     49948                             Fantasia 2000
# 1             0     10898  The Little Mermaid II: Return to the Sea
# 2      40000000      4234                                  Scream 3
# 3      23000000      2787                               Pitch Black
# 4      41300000      2069                      The Whole Nine Yards
# ...         ...       ...                                       ...
# 2796   83000000    848326    Rebel Moon - Part One: A Child of Fire
# 2797   15000000    467244                      The Zone of Interest
# 2798  205000000    572802              Aquaman and the Lost Kingdom
# 2799   25000000   1072790                            Anyone But You
# 2800   15900000    850165                             The Iron Claw
#
#                                                overview release_date  \
# 0     Blending lively music and brilliant animation,...   2000-01-01
# 1     Set several years after the first film, Ariel ...   2000-01-23
# 2     While Sidney Prescott and her friends visit th...   2000-02-04
# 3     When their ship crash-lands on a remote planet...   2000-02-18
# 4     After a mobster agrees to cooperate with an FB...   2000-02-18
# ...                                                 ...          ...
# 2796  When the ruthless forces of the Motherworld th...   2023-12-15
# 2797  The commandant of Auschwitz, Rudolf Höss, and ...   2023-12-15
# 2798  Black Manta seeks revenge on Aquaman for his f...   2023-12-20
# 2799  After an amazing first date, Bea and Ben’s fie...   2023-12-21
# 2800  The true story of the inseparable Von Erich br...   2023-12-21
#
#         revenue  runtime  vote_average  vote_count  \
# 0      60655420       74         7.000        1324
# 1             0       75         6.397        1747
# 2     161834276      116         5.995        3807
# 3      53187659      108         6.851        4599
# 4     106371651       98         6.465        1970
# ...         ...      ...           ...         ...
# 2796          0      134         6.242        2385
# 2797   52631884      105         7.005        2304
# 2798  440181226      124         6.600        3223
# 2799  214891370      103         6.837        2735
# 2800   40130232      132         7.543        1084
#
#                                     director_person_ids            genre_ids  \
# 0     [5690, 56146, 74299, 65531, 74297, 12824, 5614...   [16, 10751, 10402]
# 1                                               [60725]  [16, 12, 10751, 35]
# 2                                                [5140]           [27, 9648]
# 3                                               [28239]        [53, 878, 28]
# 4                                               [21217]             [35, 80]
# ...                                                 ...                  ...
# 2796                                            [15217]        [878, 28, 12]
# 2797                                            [66728]      [18, 36, 10752]
# 2798                                             [2127]         [28, 12, 14]
# 2799                                            [82511]          [10749, 35]
# 2800                                           [527607]             [36, 18]
#
#       collection_id                                    cast_person_ids  \
# 0           55427.0  [67773, 166002, 13301, 73931, 15152, 37221, 74...
# 1           33085.0  [63978, 67392, 15762, 35232, 67393, 9601, 7133...
# 2            2602.0  [15234, 9206, 14405, 18352, 35595, 2714, 35598...
# 3            2794.0  [12835, 8329, 6614, 28099, 26054, 65827, 28098...
# 4          103577.0  [14408, 62, 57395, 2956, 61981, 2165, 7166, 16...
# ...             ...                                                ...
# 2796       934765.0  [568657, 91520, 1047649, 938, 21688, 1564557, ...
# 2797            NaN  [71374, 7152, 4072267, 4452138, 4072269, 40722...
# 2798       573693.0  [117642, 17178, 1639847, 79082, 55085, 2227, 1...
# 2799            NaN  [115440, 83271, 3085680, 2728596, 2495673, 125...
# 2800            NaN  [29222, 206905, 1716493, 2394927, 7497, 16307,...
#
#                                         cast_credit_ids  \
# 0     ['52fe47b1c3a36847f814324f', '547f694292514123...
# 1     ['52fe43cc9251416c7501e85d', '52fe43cc9251416c...
# 2     ['52fe43b4c3a36847f806911d', '52fe43b4c3a36847...
# 3     ['52fe436dc3a36847f80535fd', '52fe436dc3a36847...
# 4     ['52fe4331c3a36847f80418c5', '52fe4331c3a36847...
# ...                                                 ...
# 2796  ['61818dfd11386c002a9b6ed9', '6250b2765a07f500...
# 2797  ['635c3ad9f28838007b15e2fe', '635c3acb88c65900...
# 2798  ['65b4239557530e0147d981bc', '5f41dea381a7fc00...
# 2799  ['63bf14f4df857c0089269b1a', '63bf1503df857c00...
# 2800  ['6326e64edcb6a3007dd98484', '6326e637dcb6a300...
#
#                                         crew_person_ids  \
# 0     [2066428, 5690, 56146, 74299, 65531, 74297, 12...
# 1     [60725, 67394, 67395, 67396, 61386, 67397, 607...
# 2     [5140, 26458, 15244, 409, 35581, 26458, 7229, ...
# 3     [28239, 13673, 28240, 9185, 63920, 63921, 1412...
# 4     [21219, 21222, 14712, 21218, 21221, 21220, 212...
# ...                                                 ...
# 2796  [3486271, 15217, 17285, 1005508, 2104243, 1830...
# 2797  [1341727, 4222, 70604, 1623709, 1389542, 41551...
# 2798  [52600, 2127, 36, 1354914, 1545447, 62813, 212...
# 2799  [1963222, 1325188, 2761446, 4321486, 4321489, ...
# 2800  [527607, 465, 2211578, 1336431, 3987582, 32604...
#
#                                         crew_credit_ids
# 0     ['624f173b24f2ce009ddf2543', '52fe47b1c3a36847...
# 1     ['52fe43cc9251416c7501e873', '52fe43cc9251416c...
# 2     ['52fe43b4c3a36847f80690cb', '52fe43b4c3a36847...
# 3     ['52fe436dc3a36847f805361f', '52fe436dc3a36847...
# 4     ['52fe4331c3a36847f8041899', '52fe4331c3a36847...
# ...                                                 ...
# 2796  ['624462cdc50ad20047008aad', '626038010792e115...
# 2797  ['620956a6fab3fa0132ea9f79', '6078629118864b00...
# 2798  ['60774e1d19ab59004062d106', '6078ca802faf4d00...
# 2799  ['652be8e4f2883802a25e99af', '652be8fa358da700...
# 2800  ['60ed282a140bad002f076acc', '60ed284651a64e00...
#
# [2801 rows x 16 columns]

# %% [markdown]
# We won't do any clean to the column Collection_id because it is for movies in a collection, like The Lord of the Rings: Fellowship of the Ring, The Lord of the Rings: The Two Towers and The Lord of the Rings: The Return of the King

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2801 entries, 0 to 2800
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   budget               2801 non-null   int64
#  1   movie_id             2801 non-null   int64
#  2   original_title       2801 non-null   object
#  3   overview             2801 non-null   object
#  4   release_date         2801 non-null   datetime64[ns]
#  5   revenue              2801 non-null   int64
#  6   runtime              2801 non-null   int64
#  7   vote_average         2801 non-null   float64
#  8   vote_count           2801 non-null   int64
#  9   director_person_ids  2801 non-null   object
#  10  genre_ids            2801 non-null   object
#  11  collection_id        894 non-null    float64
#  12  cast_person_ids      2801 non-null   object
#  13  cast_credit_ids      2801 non-null   object
#  14  crew_person_ids      2801 non-null   object
#  15  crew_credit_ids      2801 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(8)
# memory usage: 350.3+ KB

# %% [markdown]
# We check the min value of the budget to see if any are missing

# %%
print(df_movies['budget'].min())
print(df_movies.shape)
# Out:
# 0
# (2801, 16)

# %% [markdown]
# We'll check if any of the budget and revenue have the default 0

# %%
zero_budget_count = (df_movies['budget'] == 0).sum()
zero_revenue_count = (df_movies['revenue'] == 0).sum()

print(f"Rows with budget = 0: {zero_budget_count}")
print(f"Rows with revenue = 0: {zero_revenue_count}")
# Out:
# Rows with budget = 0: 308
# Rows with revenue = 0: 304

# %% [markdown]
# Since we have a large set of data and the difference movies can have in budget and revenue, we'll drop the rows with a budget or renvenue of zero to stay as close to the true data as possible

# %%
df_movies = df_movies[(df_movies['budget'] != 0) & (df_movies['revenue'] != 0)].copy()

# %% [markdown]
# Genre ids seems to have a fine spread

# %%
df_movies['genre_ids'].explode().value_counts()
# Out:
# genre_ids
# 18       909
# 35       838
# 28       774
# 53       727
# 12       614
# 878      390
# 80       386
# 10749    374
# 14       334
# 27       329
# 10751    324
# 9648     237
# 16       197
# 36       119
# 10752     63
# 10402     57
# 37        26
# 99         5
# 10770      1
# Name: count, dtype: int64

# %% [markdown]
# We also check for runtime to make sure no tv series have made its way into the data by a mistake

# %%
runtime = (df_movies['runtime'] <= 60).sum()
print(runtime)
# Out:
# 0

# %% [markdown]
# Data about actors and actress will come from persons.csv

# %%
df_persons = generic_reader.read_csv_file_to_data_frame("movie_data/persons.csv")
print(df_persons.info())
df_persons
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12475 entries, 0 to 12474
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   adult                 12475 non-null  bool
#  1   also_known_as         12475 non-null  object
#  2   biography             9339 non-null   object
#  3   birthday              9894 non-null   object
#  4   deathday              548 non-null    object
#  5   gender                12475 non-null  int64
#  6   homepage              1833 non-null   object
#  7   person_id             12475 non-null  int64
#  8   imdb_id               12149 non-null  object
#  9   known_for_department  12475 non-null  object
#  10  name                  12475 non-null  object
#  11  place_of_birth        9994 non-null   object
#  12  popularity            12475 non-null  float64
#  13  profile_path          11651 non-null  object
# dtypes: bool(1), float64(1), int64(2), object(10)
# memory usage: 1.2+ MB
# None
#        adult                                      also_known_as  \
# 0      False  ['George Walton Lucas Jr. ', 'George Walton Lu...
# 1      False  ['Mark Hamil', 'Mark Richard Hamill', 'Patrick...
# 2      False                               ['Harrison J. Ford']
# 3      False  ['Carrie Frances Fisher ', 'Кэрри Фрэнсис Фише...
# 4      False                 ['林-曼努尔·米兰达', 'لین-منوئل میراندا']
# ...      ...                                                ...
# 12470  False               ['Roxanna Ortega', 'Roxanne Ortega']
# 12471  False                                                 []
# 12472  False                                                 []
# 12473  False                              ['Egidio Cafarelli ']
# 12474  False                               ['Alice Jane Evans']
#
#                                                biography    birthday  \
# 0      George Walton Lucas Jr. (born May 14, 1944) is...  1944-05-14
# 1      Mark Richard Hamill (born September 25, 1951) ...  1951-09-25
# 2      Legendary Hollywood Icon Harrison Ford was bor...  1942-07-13
# 3      Carrie Frances Fisher (October 21, 1956 – Dece...  1956-10-21
# 4      Lin-Manuel Miranda (/mænˈwɛl/; born January 16...  1980-01-16
# ...                                                  ...         ...
# 12470                                                NaN         NaN
# 12471                                                NaN  1968-12-21
# 12472  Cynthia Stevenson (born August 2, 1962 in Oakl...  1962-08-02
# 12473  Gino Cafarelli (born 28 February 1969) is an A...  1969-02-28
# 12474                                                NaN  1968-08-02
#
#          deathday  gender                   homepage  person_id    imdb_id  \
# 0             NaN       2                        NaN          1  nm0000184
# 1             NaN       2                        NaN          2  nm0000434
# 2             NaN       2                        NaN          3  nm0000148
# 3      2016-12-27       1  https://carriefisher.com/          4  nm0000402
# 4             NaN       2  http://www.linmanuel.com/    1179651  nm0592135
# ...           ...     ...                        ...        ...        ...
# 12470         NaN       1   http://roxanaortega.com/      98292  nm0650945
# 12471         NaN       2                        NaN      65525  nm0564586
# 12472         NaN       1                        NaN      65528  nm0828906
# 12473         NaN       2                        NaN    1179643  nm1388699
# 12474         NaN       1                        NaN      65535  nm0262521
#
#       known_for_department                name  \
# 0                Directing        George Lucas
# 1                   Acting         Mark Hamill
# 2                   Acting       Harrison Ford
# 3                   Acting       Carrie Fisher
# 4                   Acting  Lin-Manuel Miranda
# ...                    ...                 ...
# 12470               Acting       Roxana Ortega
# 12471            Directing       Howard McCain
# 12472               Acting   Cynthia Stevenson
# 12473               Acting      Gino Cafarelli
# 12474               Acting         Alice Evans
#
#                                     place_of_birth  popularity  \
# 0                         Modesto, California, USA      1.6016
# 1                         Oakland, California, USA      2.3873
# 2                           Chicago, Illinois, USA      3.1719
# 3      Beverly Hills, Los Angeles, California, USA      0.8295
# 4          Manhattan, New York City, New York, USA      1.1104
# ...                                            ...         ...
# 12470                 Los Angeles, California, USA      0.2401
# 12471                                          NaN      0.9515
# 12472                    Piedmont, California, USA      0.9425
# 12473         Queens, New York City, New York, USA      0.2527
# 12474                      Summit, New Jersey, USA      0.7893
#
#                            profile_path
# 0      /mDLDvsx8PaZoEThkBdyaG1JxPdf.jpg
# 1      /2ZulC2Ccq1yv3pemusks6Zlfy2s.jpg
# 2      /zVnHagUvXkR2StdOtquEwsiwSVt.jpg
# 3      /awb4UqzT6meD3JiQlraIzAqcRtH.jpg
# 4      /r0wFwPa041pZ1QM66yJWuQXCkqx.jpg
# ...                                 ...
# 12470  /tAkMeufq6ruljugyHhjvtIe72H4.jpg
# 12471                               NaN
# 12472  /zdrsUVw9F0U4onvh1rS1AQor4wp.jpg
# 12473  /x9sMMZ9BSL21eYXCvYuLXgM3Glr.jpg
# 12474  /bnqD4yDORWpJg8uQjwsngZjZdgd.jpg
#
# [12475 rows x 14 columns]

# %%
columns_to_keep = ['birthday', 'deathday', 'gender', 'person_id', 'known_for_department']
df_persons = df_persons[columns_to_keep].copy()
df_persons['birthday'] = pd.to_datetime(df_persons['birthday'])
df_persons['deathday'] = pd.to_datetime(df_persons['deathday'])
df_persons
# Out:
#         birthday   deathday  gender  person_id known_for_department
# 0     1944-05-14        NaT       2          1            Directing
# 1     1951-09-25        NaT       2          2               Acting
# 2     1942-07-13        NaT       2          3               Acting
# 3     1956-10-21 2016-12-27       1          4               Acting
# 4     1980-01-16        NaT       2    1179651               Acting
# ...          ...        ...     ...        ...                  ...
# 12470        NaT        NaT       1      98292               Acting
# 12471 1968-12-21        NaT       2      65525            Directing
# 12472 1962-08-02        NaT       1      65528               Acting
# 12473 1969-02-28        NaT       2    1179643               Acting
# 12474 1968-08-02        NaT       1      65535               Acting
#
# [12475 rows x 5 columns]

# %% [markdown]
# Like with the release date of movies, we now change birthday and deathday to a date format.
# Then we will be dropping actors/actresses which have no data for birthday as we'll need it

# %% [markdown]
# !OBS! Det kan være vi skal vente med at droppe de persom til vi sidder med beregningerne, det kan vi lige snakke om

# %%
df_persons['birthday'] = pd.to_datetime(df_persons['birthday'], errors='coerce')
df_persons['deathday'] = pd.to_datetime(df_persons['deathday'], errors='coerce')

birthday_nat_count = df_persons['birthday'].isna().sum()

print(f"'NaT' in 'birthday' column: {birthday_nat_count}")
# Out:
# 'NaT' in 'birthday' column: 2581

# %%
df_persons = df_persons[pd.notna(df_persons['birthday'])].copy()

# %% [markdown]
# We add an 'age' column, calculating it as of December 31, 2023 for persons without a death date, which is the cutoff for movies

# %%
def calculate_age_from_row(row):
    birthday = row['birthday']
    deathday = row['deathday']
    
    if pd.isna(deathday):
        end_date = pd.to_datetime('2023-12-31')
    else:
        end_date = deathday
    
    age = end_date.year - birthday.year - ((end_date.month, end_date.day) < (birthday.month, birthday.day))
    return age


df_persons['age'] = df_persons.apply(calculate_age_from_row, axis=1)
df_persons.sort_values(by="age", ascending=False)
# Out:
#         birthday   deathday  gender  person_id known_for_department  age
# 1188  1917-08-18 2020-07-03       2       2246               Acting  102
# 11826 1909-05-13 2012-01-09       1      63217               Acting  102
# 8027  1913-11-16 2015-05-04       1      85171               Acting  101
# 1350  1924-07-04        NaT       1       2639               Acting   99
# 2722  1922-01-17 2021-12-31       1      71727               Acting   99
# ...          ...        ...     ...        ...                  ...  ...
# 5795  2015-06-14        NaT       2    2143772               Acting    8
# 9335  2015-09-16        NaT       1    2283930               Acting    8
# 5796  2015-06-14        NaT       2    2143771               Acting    8
# 92    2016-01-01        NaT       1    2785418               Acting    7
# 5008  2008-05-20 2016-03-20       1    1650158               Acting    7
#
# [9894 rows x 6 columns]

# %% [markdown]
# Lastly we add the column movie_count to the df_persons.
# This include all movies they have been part of as both cast and direcetor.
# First we turn the lists from director_person_ids and cast_person_ids into individual rows.
# Then we rename the director_person_ids and cast_person_ids into person_id.
# Combining the to dataframes into one.
# Then we count the how many times an id appears and map it the column movie_count in the df_persons.

# %%
cast_counts = df_movies[['cast_person_ids']].explode('cast_person_ids')
director_counts = df_movies[['director_person_ids']].explode('director_person_ids')

cast_counts = cast_counts.rename(columns={'cast_person_ids': 'person_id'})
director_counts = director_counts.rename(columns={'director_person_ids': 'person_id'})

all_counts = pd.concat([cast_counts, director_counts], ignore_index=True)

person_movie_count = all_counts['person_id'].value_counts()

df_persons['movie_count'] = df_persons['person_id'].map(person_movie_count).fillna(0).astype(int)

# %%
asd = (df_persons['movie_count'] == 0).sum()
print(asd)
# Out:
# 628

# %% [markdown]
# Dropping persons which have movie_count of 0.

# %%
df_persons = df_persons[(df_persons['movie_count'] != 0)].copy()

# %% [markdown]
# The cleaning process results in two dataframes, df_movies and df_persons.
# df_movies contain 2406 movies and df_persons contain 9266 acotrs/actresses/directors.

# %%
print("df_persons:", df_persons.shape)
print("df_movies:", df_movies.shape)
# Out:
# df_persons: (9266, 7)
# df_movies: (2406, 16)
