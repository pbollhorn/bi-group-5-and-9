# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv
from time import sleep

load_dotenv()
tmdb_api_token = os.getenv("TMDB_API_TOKEN")

base_url = (
    "https://api.themoviedb.org/3/discover/movie"
    "?include_adult=false"
    "&include_video=false"
    "&language=en-US"
    "&sort_by=primary_release_date.asc"
    "&with_original_language=da"
    "&primary_release_date.gte=2020-01-01"
    "&primary_release_date.lte=2024-12-31"
)

headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {tmdb_api_token}"
}

all_results = []

# Loop through all pages (adjust max page if needed)
for page in range(1, 500):
    url = f"{base_url}&page={page}"
    resp = requests.get(url, headers=headers).json()

    # Stop if we reach the last page
    if "results" not in resp or not resp["results"]:
        break

    all_results.extend(resp["results"])
    sleep(0.02)  # Just to be sure we don't request too many requests

print(all_results)

df_movies = pd.DataFrame(all_results)

print(df_movies)

print(f"Total movies collected: {len(df_movies)}")

output_folder = os.path.join(os.getcwd(), "movie_data")
output_path = os.path.join(output_folder, "danish_movies_upto_2024.csv")
df_movies.to_csv(output_path, index=False)
# Out:
# [{'adult': False, 'backdrop_path': None, 'genre_ids': [99, 10770], 'id': 1389683, 'original_language': 'da', 'original_title': 'Den gamle mand og skoven', 'overview': '', 'popularity': 0.0256, 'poster_path': None, 'release_date': '2020-01-01', 'title': 'Den gamle mand og skoven', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': None, 'genre_ids': [99], 'id': 1275299, 'original_language': 'da', 'original_title': 'Badabing og Bang - Hurra, årtiet er slut!', 'overview': '', 'popularity': 0.0071, 'poster_path': None, 'release_date': '2020-01-01', 'title': 'Badabing og Bang - Hurra, årtiet er slut!', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': None, 'genre_ids': [18], 'id': 1176704, 'original_language': 'da', 'original_title': 'Stime', 'overview': "During the summer, the relationship between two brothers is set to the test when they join the older brother's friends at the harbor.", 'popularity': 0.4993, 'poster_path': '/gIeKc1t6NvU1K7aBMWBtFiZT83.jpg', 'release_date': '2020-01-01', 'title': 'Stime', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/3tdNtSbcMliHlWnxt5fVuiL6QmO.jpg', 'genre_ids': [35], 'id': 660040, 'original_language': 'da', 'original_title': 'Grin til gavn 2019', 'overview': "In keeping with tradition, the popular comedy show is back, and this time it is Red Barnet that is behind it. This year's hosts are Michael Schøt and Christian Fuhlendorff.", 'popularity': 1.2027, 'poster_path': '/li1AH754TAWztgyadRvT0BoZqRr.jpg', 'release_date': '2020-01-01', 'title': 'Grin til gavn 2019', 'video': False, 'vote_average': 6.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': '/w2T6QLixu8X6C5FlfpKDglIFcJ4.jpg', 'genre_ids': [99], 'id': 661167, 'original_language': 'da', 'original_title': 'Et langsomt mord', 'overview': '', 'popularity': 0.0071, 'poster_path': '/il5Q47C5tYw6QtzGBfokVI97ywi.jpg', 'release_date': '2020-01-03', 'title': 'Et langsomt mord', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': None, 'genre_ids': [], 'id': 724602, 'original_language': 'da', 'original_title': 'Udkant', 'overview': 'Young Copenhagener Mads goes in search of authenticity in rural Denmark. Together with his girlfriend, he goes on a weekend trip into the countryside, where they meet another couple who challenge his preconceptions. Mads breaks with his own ideals and resorts to extremes in order not to lose face.', 'popularity': 0.5988, 'poster_path': None, 'release_date': '2020-01-06', 'title': 'Udkant', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/TRfZEQSG8C9MNLxi3gs4s8aIwi.jpg', 'genre_ids': [18, 10752, 36], 'id': 639514, 'original_language': 'da', 'original_title': 'De forbandede år', 'overview': 'Karlskov is a self made, successful owner of a large electronics factory, has a wife and five children. They live the good, privileged upper-class life on Strandvejen north of Copenhagen when the Nazis occupy Denmark in April 1940. Karl struggles to continue production at the factory, but to protect his family and employees he reluctantly begins to produce for the German market. It brings him into a controversial collaboration with the occupying power and causes painful breaks in the family.', 'popularity': 0.6956, 'poster_path': '/1szNN4QorfoL9s9GKr4unE0av3X.jpg', 'release_date': '2020-01-09', 'title': 'Into the Darkness', 'video': False, 'vote_average': 6.1, 'vote_count': 42}, {'adult': False, 'backdrop_path': '/4kdE8nOsuGHsJwHjgm40T14T5OW.jpg', 'genre_ids': [35], 'id': 663692, 'original_language': 'da', 'original_title': 'Lars Hjortshøj: Plan B', 'overview': '', 'popularity': 0.3534, 'poster_path': '/d5TQVEqTLPFRsc9EM2BtnXvgzAS.jpg', 'release_date': '2020-01-13', 'title': 'Lars Hjortshøj: Plan B', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/jnolZ06zB2rkMYzGcC0uk1NmF5Y.jpg', 'genre_ids':  ...
#      adult                     backdrop_path    genre_ids       id  \
# 0    False                              None  [99, 10770]  1389683
# 1    False                              None         [99]  1275299
# 2    False                              None         [18]  1176704
# 3    False  /3tdNtSbcMliHlWnxt5fVuiL6QmO.jpg         [35]   660040
# 4    False  /w2T6QLixu8X6C5FlfpKDglIFcJ4.jpg         [99]   661167
# ..     ...                               ...          ...      ...
# 926  False   /MSP35R6y0ypmf3zU1kyUw1P4It.jpg         [35]  1407803
# 927  False  /2iVVzCEnX4QMEeyd3e52juYcsH8.jpg           []  1410638
# 928  False  /ej5uQVMJTzq8nZBCbf6pUMNF6jl.jpg         [35]  1409581
# 929  False                              None         [35]  1412034
# 930  False  /dnUO6DSBtGnez743z0dwJ0kRM0o.jpg           []  1410006
#
#     original_language                                     original_title  \
# 0                  da                           Den gamle mand og skoven
# 1                  da          Badabing og Bang - Hurra, årtiet er slut!
# 2                  da                                              Stime
# 3                  da                                 Grin til gavn 2019
# 4                  da                                   Et langsomt mord
# ..                ...                                                ...
# 926                da                       Verdensmænd - Bobos surprise
# 927                da                                 Gud bevare Danmark
# 928                da                                Frank Hvam - Nobody
# 929                da  Dan Andersen - Nedsat Hørelse, Nedsat Sædkvali...
# 930                da                       Jan Hellesøe - Forudsigelser
#
#                                               overview  popularity  \
# 0                                                           0.0256
# 1                                                           0.0071
# 2    During the summer, the relationship between tw...      0.4993
# 3    In keeping with tradition, the popular comedy ...      1.2027
# 4                                                           0.0071
# ..                                                 ...         ...
# 926                                                         0.5790
# 927                                                         0.0000
# 928  Frank Hvam has lived in New Zealand with his f...      0.0338
# 929                                                         0.0143
# 930                                                         0.0919
#
#                           poster_path release_date  \
# 0                                None   2020-01-01
# 1                                None   2020-01-01
# 2     /gIeKc1t6NvU1K7aBMWBtFiZT83.jpg   2020-01-01
# 3    /li1AH754TAWztgyadRvT0BoZqRr.jpg   2020-01-01
# 4    /il5Q47C5tYw6QtzGBfokVI97ywi.jpg   2020-01-03
# ..                                ...          ...
# 926  /gj78vKF4kxp0j9Q1Op8mi12I6kd.jpg   2024-12-26
# 927                              None   2024-12-30
# 928  /tbsteDb5jFpsrmCxzqiVWerYgyQ.jpg   2024-12-30
# 929  /4t5AFH7VhSv7c67KLpMveEc95Wn.jpg   2024-12-31
# 930  /eZwEZZqS8dzGtTZFWRoNvliLrwp.jpg   2024-12-31
#
#                                                  title  video  vote_average  \
# 0                             Den gamle mand og skoven  False           0.0
# 1            Badabing og Bang - Hurra, årtiet er slut!  False           0.0
# 2                                                Stime  False           0.0
# 3                                   Grin til gavn 2019  False           6.0
# 4                                     Et langsomt mord  False           0.0
# ..                                                 ...    ...           ...
# 926                       Verdensmænd - Bobos surprise  False          10.0
# 927                                 Gud bevare Danmark  False           0.0
# 928                                Frank Hvam - Nobody  False           6.0
# 929  Dan Andersen - Nedsat Hørelse, Nedsat Sædkvali...  False           0.0
# 930                       Jan Hellesøe - Forudsigelser  False           0.0
#
#      vote_count
# 0             0
# 1             0
# 2             0
# 3             1
# 4             0
# ..          ...
# 926           1
# 927           0
# 928           1
# 929           0
# 930           0
#
# [931 rows x 14 columns]
# Total movies collected: 931

# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv
from time import sleep

load_dotenv()
tmdb_api_token = os.getenv("TMDB_API_TOKEN")

headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {tmdb_api_token}"
}

# Make sure df_movies is already loaded or created before this section
movie_ids = df_movies["id"].tolist()

all_results = []

# Loop through all movie_ids
for movie_id in movie_ids:
    url = f"https://api.themoviedb.org/3/movie/{movie_id}?language=en-US"
    resp = requests.get(url, headers=headers).json()
    all_results.append(resp)
    sleep(0.02)  # Just to be sure we don't request too many requests

print(all_results)

df_movies = pd.DataFrame(all_results)
print(f"Total movies collected: {len(df_movies)}")

output_folder = os.path.join(os.getcwd(), "movie_data")
output_path = os.path.join(output_folder, "alt.csv")
df_movies.to_csv(output_path, index=False)
# Out:
# [{'adult': False, 'backdrop_path': None, 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 99, 'name': 'Documentary'}, {'id': 10770, 'name': 'TV Movie'}], 'homepage': '', 'id': 1389683, 'imdb_id': None, 'origin_country': ['DK'], 'original_language': 'da', 'original_title': 'Den gamle mand og skoven', 'overview': '', 'popularity': 0.0256, 'poster_path': None, 'production_companies': [{'id': 119, 'logo_path': '/1di2gITGUZr730AMuMKiCrP90Vl.png', 'name': 'DR', 'origin_country': 'DK'}], 'production_countries': [], 'release_date': '2020-01-01', 'revenue': 0, 'runtime': 0, 'spoken_languages': [], 'status': 'Released', 'tagline': '', 'title': 'Den gamle mand og skoven', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': None, 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 99, 'name': 'Documentary'}], 'homepage': '', 'id': 1275299, 'imdb_id': None, 'origin_country': ['DK'], 'original_language': 'da', 'original_title': 'Badabing og Bang - Hurra, årtiet er slut!', 'overview': '', 'popularity': 0.0071, 'poster_path': None, 'production_companies': [{'id': 119, 'logo_path': '/1di2gITGUZr730AMuMKiCrP90Vl.png', 'name': 'DR', 'origin_country': 'DK'}], 'production_countries': [{'iso_3166_1': 'DK', 'name': 'Denmark'}], 'release_date': '2020-01-01', 'revenue': 0, 'runtime': 0, 'spoken_languages': [{'english_name': 'Danish', 'iso_639_1': 'da', 'name': 'Dansk'}], 'status': 'Released', 'tagline': '', 'title': 'Badabing og Bang - Hurra, årtiet er slut!', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': None, 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 18, 'name': 'Drama'}], 'homepage': '', 'id': 1176704, 'imdb_id': 'tt26752729', 'origin_country': ['DK'], 'original_language': 'da', 'original_title': 'Stime', 'overview': "During the summer, the relationship between two brothers is set to the test when they join the older brother's friends at the harbor.", 'popularity': 0.4993, 'poster_path': '/gIeKc1t6NvU1K7aBMWBtFiZT83.jpg', 'production_companies': [{'id': 166089, 'logo_path': '/ldJWPQcyyeO87YFh0nFwRTnCtXY.png', 'name': 'Filmværkstedet København', 'origin_country': 'DK'}], 'production_countries': [{'iso_3166_1': 'DK', 'name': 'Denmark'}], 'release_date': '2020-01-01', 'revenue': 0, 'runtime': 10, 'spoken_languages': [{'english_name': 'Danish', 'iso_639_1': 'da', 'name': 'Dansk'}], 'status': 'Released', 'tagline': '', 'title': 'Stime', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/3tdNtSbcMliHlWnxt5fVuiL6QmO.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 35, 'name': 'Comedy'}], 'homepage': '', 'id': 660040, 'imdb_id': None, 'origin_country': ['DK'], 'original_language': 'da', 'original_title': 'Grin til gavn 2019', 'overview': "In keeping with tradition, the popular comedy show is back, and this time it is Red Barnet that is behind it. This year's hosts are Michael Schøt and Christian Fuhlendorff.", 'popularity': 1.2027, 'poster_path': '/li1AH754TAWztgyadRvT0BoZqRr.jpg', 'production_companies': [{'id': 20632, 'logo_path': None, 'name': 'Red barnet', 'origin_country': ''}], 'production_countries': [{'iso_3166_1': 'DK', 'name': 'Denmark'}], 'release_date': '2020-01-01', 'revenue': 0, 'runtime': 0, 'spoken_languages': [{'english_name': 'Danish', 'iso_639_1': 'da', 'name': 'Dansk'}], 'status': 'Released', 'tagline': '', 'title': 'Grin til gavn 2019', 'video': False, 'vote_average': 6.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': '/w2T6QLixu8X6C5FlfpKDglIFcJ4.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 99, 'name': 'Documentary'}], 'homepage': '', 'id': 661167, 'imdb_id': None, 'origin_country': ['DK'], 'original_language': 'da', 'original_title': 'Et langsomt mord', 'overview': '', 'popularity': 0.0071, 'poster_path': '/il5Q47C5tYw6QtzGBfokVI97ywi.jpg', 'production_companies': [{'id': 639, 'logo_path': '/fNhXK0DtWWGh7Diy10kPvKPLk5h.png', ' ...
# Total movies collected: 931

# %%
df_movies
# Out:
#      adult                     backdrop_path belongs_to_collection  budget  \
# 0    False                              None                  None       0
# 1    False                              None                  None       0
# 2    False                              None                  None       0
# 3    False  /3tdNtSbcMliHlWnxt5fVuiL6QmO.jpg                  None       0
# 4    False  /w2T6QLixu8X6C5FlfpKDglIFcJ4.jpg                  None       0
# ..     ...                               ...                   ...     ...
# 926  False   /MSP35R6y0ypmf3zU1kyUw1P4It.jpg                  None       0
# 927  False  /2iVVzCEnX4QMEeyd3e52juYcsH8.jpg                  None       0
# 928  False  /ej5uQVMJTzq8nZBCbf6pUMNF6jl.jpg                  None       0
# 929  False                              None                  None       0
# 930  False  /dnUO6DSBtGnez743z0dwJ0kRM0o.jpg                  None       0
#
#                                                 genres homepage       id  \
# 0    [{'id': 99, 'name': 'Documentary'}, {'id': 107...           1389683
# 1                  [{'id': 99, 'name': 'Documentary'}]           1275299
# 2                        [{'id': 18, 'name': 'Drama'}]           1176704
# 3                       [{'id': 35, 'name': 'Comedy'}]            660040
# 4                  [{'id': 99, 'name': 'Documentary'}]            661167
# ..                                                 ...      ...      ...
# 926                     [{'id': 35, 'name': 'Comedy'}]           1407803
# 927                                                 []           1410638
# 928                     [{'id': 35, 'name': 'Comedy'}]           1409581
# 929                     [{'id': 35, 'name': 'Comedy'}]           1412034
# 930                                                 []           1410006
#
#         imdb_id origin_country original_language  ... release_date revenue  \
# 0          None           [DK]                da  ...   2020-01-01       0
# 1          None           [DK]                da  ...   2020-01-01       0
# 2    tt26752729           [DK]                da  ...   2020-01-01       0
# 3          None           [DK]                da  ...   2020-01-01       0
# 4          None           [DK]                da  ...   2020-01-03       0
# ..          ...            ...               ...  ...          ...     ...
# 926        None           [DK]                da  ...   2024-12-26       0
# 927        None           [DK]                da  ...   2024-12-30       0
# 928        None           [DK]                da  ...   2024-12-30       0
# 929        None           [DK]                da  ...   2024-12-31       0
# 930        None           [DK]                da  ...   2024-12-31       0
#
#      runtime                                   spoken_languages    status  \
# 0          0                                                 []  Released
# 1          0  [{'english_name': 'Danish', 'iso_639_1': 'da',...  Released
# 2         10  [{'english_name': 'Danish', 'iso_639_1': 'da',...  Released
# 3          0  [{'english_name': 'Danish', 'iso_639_1': 'da',...  Released
# 4          0                                                 []  Released
# ..       ...                                                ...       ...
# 926        0  [{'english_name': 'Danish', 'iso_639_1': 'da',...  Released
# 927        0  [{'english_name': 'Danish', 'iso_639_1': 'da',...  Released
# 928       56  [{'english_name': 'Danish', 'iso_639_1': 'da',...  Released
# 929        0  [{'english_name': 'Danish', 'iso_639_1': 'da',...  Released
# 930        0  [{'english_name': 'Danish', 'iso_639_1': 'da',...  Released
#
#     tagline                                              title  video  \
# 0                                     Den gamle mand og skoven  False
# 1                    Badabing og Bang - Hurra, årtiet er slut!  False
# 2                                                        Stime  False
# 3                                           Grin til gavn 2019  False
# 4                                             Et langsomt mord  False
# ..      ...                                                ...    ...
# 926                               Verdensmænd - Bobos surprise  False
# 927                                         Gud bevare Danmark  False
# 928                                        Frank Hvam - Nobody  False
# 929          Dan Andersen - Nedsat Hørelse, Nedsat Sædkvali...  False
# 930                               Jan Hellesøe - Forudsigelser  False
#
#      vote_average vote_count
# 0             0.0          0
# 1             0.0          0
# 2             0.0          0
# 3             6.0          1
# 4             0.0          0
# ..            ...        ...
# 926          10.0          1
# 927           0.0          0
# 928           6.0          1
# 929           0.0          0
# 930           0.0          0
#
# [931 rows x 26 columns]
